# %%
# %matplotlib inline 
import matplotlib.pyplot as plt

import numpy as np 
import scipy.io as sio

# %%
torque_time = [0, 1, 2.5, 4, 5.5, 7, 8.5, 10]
torque = [0, 0, 0, 0, 0, 0, 0, 0]
speed_time = [0, 1, 2.5, 4, 5.5, 7, 8.5, 10]
speed = [0, 0, 50, 50, -50, -50, 25, 25]

# %%
plt.plot(torque_time, torque)
plt.show()
plt.plot(speed_time, speed)
plt.show()

# %%
torque_time = [0, 1, 2.5, 4, 5.5, 7, 8.5, 10, 11.5, 13]
torque = [0, 0, 100, 100, 100, 100, 100, 100, 100, 100]
speed_time = [0, 1, 2.5, 4, 5.5, 7, 8.5, 10, 11.5, 13]
speed = [0, 0, 0, 0, 50, 50, -50, -50, 25, 25]

# %%
plt.plot(torque_time, torque)
plt.show()
plt.plot(speed_time, speed)
plt.show()
